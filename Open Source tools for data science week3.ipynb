# %% [markdown]
# # My Jupyter Notebook on IBM Data Science Experience

# %% [markdown]
# **TRAN TUAN VU**
#
#  Data Science

# %% [markdown]
# *I like Data Science because I want to solve the core problem that relates to business, finance, etc*

# %% [markdown]
# ### print(10+1)

# %%
print(10+1)
# Out:
# 11

# %% [markdown]
# Three or more...
#
# ---
#
# Hyphens
#
# ***
#
# Asterisks
#
# ___
#
# Underscores
#
# ***
#
# * Fish
# * Eggs
# * Cheese
#
# ***
#
# 1. Fish
# 2. Eggs
# 3. Cheese
#
# ***
#
# |Name  |Address     |Salary   |
# |------|------------|---------|
# |Hanna |Brisbane    |4000     |
# |Adam  |Sydney      |5000     |
#
#
# ***
# [here is the google link](https://www.google.com)
#
# ***
# Code/syntax `highlighting`
#
# ***
# > This is Blockquotes
#
# ***
# ~~This is Strikethrough~~
